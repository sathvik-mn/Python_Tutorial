# %%
import pandas as pd
import numpy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:/Learning/Python/groceries.csv')

# %%
data.shape
# Out:
# (3090, 9)

# %%
data.head(20)
# Out:
#                             1                    2                      3  \
# 0                citrus fruit  semi-finished bread              margarine
# 1              tropical fruit               yogurt                 coffee
# 2                  whole milk                  NaN                    NaN
# 3                   pip fruit               yogurt          cream cheese
# 4            other vegetables           whole milk         condensed milk
# 5                  whole milk               butter                 yogurt
# 6                  rolls/buns                  NaN                    NaN
# 7            other vegetables             UHT-milk             rolls/buns
# 8                  pot plants                  NaN                    NaN
# 9                  whole milk              cereals                    NaN
# 10             tropical fruit     other vegetables            white bread
# 11               citrus fruit       tropical fruit             whole milk
# ...

# %%
data.columns = ['A','S','d','f','g','h','j','k','l']

# %%
data
# Out:
#                        A                    S                 d  \
# 0           citrus fruit  semi-finished bread         margarine
# 1         tropical fruit               yogurt            coffee
# 2             whole milk                  NaN               NaN
# 3              pip fruit               yogurt     cream cheese
# 4       other vegetables           whole milk    condensed milk
# ...                  ...                  ...               ...
# 3085  whipped/sour cream        domestic eggs     bottled water
# 3086      tropical fruit            pip fruit  other vegetables
# 3087            UHT-milk          canned beer               NaN
# 3088     root vegetables  semi-finished bread     specialty bar
# 3089         frankfurter              sausage            butter
#
#                              f              g                   h         j  \
# 0                  ready soups            NaN                 NaN       NaN
# ...

# %%
data.dtypes
# Out:
# A    object
# S    object
# d    object
# f    object
# g    object
# h    object
# j    object
# k    object
# l    object
# dtype: object

# %%
data.describe()
# Out:
#               A           S           d           f           g           h  \
# count      3090        2423        1896        1504        1176         894
# unique      133         133         134         134         134         117
# top     sausage  whole milk  whole milk  whole milk  rolls/buns  rolls/buns
# freq        235         192         179         103          62          50
#
#            j              k              l
# count    697            523            390
# unique   118            107            103
# top     soda  bottled water  bottled water
# freq      36             26             25

# %%
data.isnull().sum()
# Out:
# A       0
# S     667
# d    1194
# f    1586
# g    1914
# h    2196
# j    2393
# k    2567
# l    2700
# dtype: int64

# %%
data.groupby('d')

# %%
sns.histplot(data['d'], bins =200)
# Out:
# <Axes: xlabel='d', ylabel='Count'>

# %%
a = 2**4
a
# Out:
# 16

# %%
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
#                           A    S    d    f    g    h    j    k    l
# 22               whole milk  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28         other vegetables  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36    fruit/vegetable juice  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43              canned beer  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 47               rolls/buns  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...
# 3070                   soda  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3074         sparkling wine  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3076                   soda  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3080              chocolate  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3082                 coffee  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [731 rows x 9 columns]

# %%
# Check for duplicates in 'column1'
duplicates_in_column1 = data[data.duplicated(['d'])]
print(duplicates_in_column1)
# Out:
#                        A                    S                 d            f  \
# 6             rolls/buns                  NaN               NaN          NaN
# 8             pot plants                  NaN               NaN          NaN
# 9             whole milk              cereals               NaN          NaN
# 12                  beef                  NaN               NaN          NaN
# 14               chicken       tropical fruit               NaN          NaN
# ...                  ...                  ...               ...          ...
# 3085  whipped/sour cream        domestic eggs     bottled water         soda
# 3086      tropical fruit            pip fruit  other vegetables  butter milk
# 3087            UHT-milk          canned beer               NaN          NaN
# 3088     root vegetables  semi-finished bread     specialty bar          NaN
# 3089         frankfurter              sausage            butter      dessert
#
# ...
